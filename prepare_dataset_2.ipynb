# %% [markdown]
# ## Use the full CDS for TFs, and promoter for genes
# ### Also, avoid using sequences in dataframe, use the names only. Keep sequences in a dict instead.

# %% [markdown]
# # Dataset control values

# %%
BP_considered = 2000 # base pairs upstream and downstream
FILTER_TF = True # only keep tfs that were marked as active in the data

# %% [markdown]
# ## Read perturbation data

# %%
from tqdm import tqdm

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('RPE1_CRISPRa_mean_pop.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10912 × 5424
#     obs: 'protospacer', 'target_gene', 'target_expr', 'active', 'cluster', 'cluster_name', 'cluster_description', 'gene_driven', 'sequence_driven', 'sequence_suffix', 'bulk_expr', 'expressed', 'p_expressed', 'de_genes', 'strength', 'cell_count', 'target_gene_id', 'masked_active', 'masked_cluster', 'masked_cluster_name', 'masked_cluster_description', 'masked_cluster_size', 'masked_cluster_num_genes', 'stricter_masked_cluster', 'stricter_masked_cluster_description'
#     var: 'feature_types', 'genome', 'mean', 'in_matrix', 'std', 'cv', 'fano', 'pairwise_p_cost', 'mean_adjusted_pairwise_p_cost', 'excess_cv', 'pairwise_chosen', 'gene_id'
#     layers: 'adj_p', 'masked', 'p'

# %%
adata.obs
# Out:
#                                           protospacer target_gene  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT        GCGCAGAAGGTTGAAGGGAT        AATF
# AATF_GCGTGCGAGTGCGCGGGAAG        GCGTGCGAGTGCGCGGGAAG        AATF
# AATF_GGAAGCGCGCAGAAGGTTGA        GGAAGCGCGCAGAAGGTTGA        AATF
# AATF_GGAAGGGATTGGAGCCGTAT        GGAAGGGATTGGAGCCGTAT        AATF
# AATF_GGGCGTTGCTAGCATGAAGG        GGGCGTTGCTAGCATGAAGG        AATF
# ...                                               ...         ...
# off-target_GGGAACAGGGGCGGTCCGTA  GGGAACAGGGGCGGTCCGTA  off-target
# off-target_GTAAATTCTCGCGTAACGTT  GTAAATTCTCGCGTAACGTT  off-target
# off-target_GTCCATAGGGTCTAGCGCCG  GTCCATAGGGTCTAGCGCCG  off-target
# off-target_GTGGATTATCTGACGCGAAT  GTGGATTATCTGACGCGAAT  off-target
# off-target_GTTGATCGACCGATTGCGAT  GTTGATCGACCGATTGCGAT  off-target
#
#                                  target_expr  active  cluster cluster_name  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT           2.898099   False    372.0          NaN
# AATF_GCGTGCGAGTGCGCGGGAAG           1.635568   False    918.0          NaN
# AATF_GGAAGCGCGCAGAAGGTTGA           2.614520    True   2187.0       AATF_1
# AATF_GGAAGGGATTGGAGCCGTAT           1.581901    True   2187.0       AATF_1
# AATF_GGGCGTTGCTAGCATGAAGG           2.612676   False   1112.0          NaN
# ...                                      ...     ...      ...          ...
# off-target_GGGAACAGGGGCGGTCCGTA          NaN   False    161.0          NaN
# off-target_GTAAATTCTCGCGTAACGTT          NaN   False   2142.0          NaN
# off-target_GTCCATAGGGTCTAGCGCCG          NaN   False    395.0          NaN
# off-target_GTGGATTATCTGACGCGAAT          NaN   False   2307.0          NaN
# off-target_GTTGATCGACCGATTGCGAT          NaN   False    584.0          NaN
#
#                                                cluster_description  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT        372: SEQUENCE-driven (GGGAT) (13)
# AATF_GCGTGCGAGTGCGCGGGAAG                    singleton (GGAAG) (1)
# AATF_GGAAGCGCGCAGAAGGTTGA                        2187: neither (6)
# AATF_GGAAGGGATTGGAGCCGTAT                        2187: neither (6)
# AATF_GGGCGTTGCTAGCATGAAGG                    singleton (GAAGG) (1)
# ...                                                            ...
# off-target_GGGAACAGGGGCGGTCCGTA                  161: neither (45)
# off-target_GTAAATTCTCGCGTAACGTT                  2142: neither (7)
# off-target_GTCCATAGGGTCTAGCGCCG    395: SEQUENCE-driven (CCG) (48)
# off-target_GTGGATTATCTGACGCGAAT                 2307: neither (39)
# off-target_GTTGATCGACCGATTGCGAT                   584: neither (7)
#
#                                  gene_driven  sequence_driven sequence_suffix  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT              False             True           GGGAT
# AATF_GCGTGCGAGTGCGCGGGAAG              False            False
# AATF_GGAAGCGCGCAGAAGGTTGA              False            False
# AATF_GGAAGGGATTGGAGCCGTAT              False            False
# AATF_GGGCGTTGCTAGCATGAAGG              False            False
# ...                                      ...              ...             ...
# off-target_GGGAACAGGGGCGGTCCGTA        False            False
# off-target_GTAAATTCTCGCGTAACGTT        False            False
# off-target_GTCCATAGGGTCTAGCGCCG        False             True             CCG
# off-target_GTGGATTATCTGACGCGAAT        False            False
# off-target_GTTGATCGACCGATTGCGAT        False            False
#
#                                  ...  cell_count   target_gene_id  \
# guide_identity                   ...
# AATF_GCGCAGAAGGTTGAAGGGAT        ...       116.0  ENSG00000275700
# AATF_GCGTGCGAGTGCGCGGGAAG        ...        53.0  ENSG00000275700
# AATF_GGAAGCGCGCAGAAGGTTGA        ...       102.0  ENSG00000275700
# AATF_GGAAGGGATTGGAGCCGTAT        ...       108.0  ENSG00000275700
# AATF_GGGCGTTGCTAGCATGAAGG        ...        67.0  ENSG00000275700
# ...                              ...         ...              ...
# off-target_GGGAACAGGGGCGGTCCGTA  ...      1721.0              NaN
# off-target_GTAAATTCTCGCGTAACGTT  ...       454.0              NaN
# off-target_GTCCATAGGGTCTAGCGCCG  ...       813.0              NaN
# off-target_GTGGATTATCTGACGCGAAT  ...       389.0              NaN
# off-target_GTTGATCGACCGATTGCGAT  ...       474.0              NaN
#
#                                  masked_active  masked_cluster  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT                False          1479.0
# AATF_GCGTGCGAGTGCGCGGGAAG                False           237.0
# AATF_GGAAGCGCGCAGAAGGTTGA                False          1929.0
# AATF_GGAAGGGATTGGAGCCGTAT                False          1094.0
# AATF_GGGCGTTGCTAGCATGAAGG                False           183.0
# ...                                        ...             ...
# off-target_GGGAACAGGGGCGGTCCGTA          False          1138.0
# off-target_GTAAATTCTCGCGTAACGTT          False          1131.0
# off-target_GTCCATAGGGTCTAGCGCCG          False          1416.0
# off-target_GTGGATTATCTGACGCGAAT          False          2291.0
# off-target_GTTGATCGACCGATTGCGAT          False          1606.0
#
#                                  masked_cluster_name  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT                        NaN
# AATF_GCGTGCGAGTGCGCGGGAAG                        NaN
# AATF_GGAAGCGCGCAGAAGGTTGA                        NaN
# AATF_GGAAGGGATTGGAGCCGTAT                        NaN
# AATF_GGGCGTTGCTAGCATGAAGG                        NaN
# ...                                              ...
# off-target_GGGAACAGGGGCGGTCCGTA                  NaN
# off-target_GTAAATTCTCGCGTAACGTT                  NaN
# off-target_GTCCATAGGGTCTAGCGCCG                  NaN
# off-target_GTGGATTATCTGACGCGAAT                  NaN
# off-target_GTTGATCGACCGATTGCGAT                  NaN
#
#                                          masked_cluster_description  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT        1479: SEQUENCE-driven (GGGAT) (13)
# AATF_GCGTGCGAGTGCGCGGGAAG                     singleton (GGAAG) (1)
# AATF_GGAAGCGCGCAGAAGGTTGA                         1929: neither (4)
# AATF_GGAAGGGATTGGAGCCGTAT                         1094: neither (6)
# AATF_GGGCGTTGCTAGCATGAAGG                     singleton (GAAGG) (1)
# ...                                                             ...
# off-target_GGGAACAGGGGCGGTCCGTA    1138: SEQUENCE-driven (GTA) (19)
# off-target_GTAAATTCTCGCGTAACGTT                   1131: neither (7)
# off-target_GTCCATAGGGTCTAGCGCCG    1416: SEQUENCE-driven (CCG) (30)
# off-target_GTGGATTATCTGACGCGAAT                  2291: neither (24)
# off-target_GTTGATCGACCGATTGCGAT                   1606: neither (7)
#
#                                 masked_cluster_size  masked_cluster_num_genes  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT                      13.0                      13.0
# AATF_GCGTGCGAGTGCGCGGGAAG                       1.0                       1.0
# AATF_GGAAGCGCGCAGAAGGTTGA                       4.0                       4.0
# AATF_GGAAGGGATTGGAGCCGTAT                       6.0                       6.0
# AATF_GGGCGTTGCTAGCATGAAGG                       1.0                       1.0
# ...                                             ...                       ...
# off-target_GGGAACAGGGGCGGTCCGTA                19.0                      19.0
# off-target_GTAAATTCTCGCGTAACGTT                 7.0                       7.0
# off-target_GTCCATAGGGTCTAGCGCCG                30.0                      30.0
# off-target_GTGGATTATCTGACGCGAAT                24.0                      24.0
# off-target_GTTGATCGACCGATTGCGAT                 7.0                       7.0
#
#                                  stricter_masked_cluster  \
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT                         2041.0
# AATF_GCGTGCGAGTGCGCGGGAAG                          323.0
# AATF_GGAAGCGCGCAGAAGGTTGA                         2685.0
# AATF_GGAAGGGATTGGAGCCGTAT                         1437.0
# AATF_GGGCGTTGCTAGCATGAAGG                          265.0
# ...                                                  ...
# off-target_GGGAACAGGGGCGGTCCGTA                   1510.0
# off-target_GTAAATTCTCGCGTAACGTT                   1499.0
# off-target_GTCCATAGGGTCTAGCGCCG                   1953.0
# off-target_GTGGATTATCTGACGCGAAT                   3255.0
# off-target_GTTGATCGACCGATTGCGAT                   2232.0
#
#                                 stricter_masked_cluster_description
# guide_identity
# AATF_GCGCAGAAGGTTGAAGGGAT         2041: SEQUENCE-driven (GGGAT) (7)
# AATF_GCGTGCGAGTGCGCGGGAAG                     singleton (GGAAG) (1)
# AATF_GGAAGCGCGCAGAAGGTTGA                         2685: neither (4)
# AATF_GGAAGGGATTGGAGCCGTAT                         1437: neither (4)
# AATF_GGGCGTTGCTAGCATGAAGG                     singleton (GAAGG) (1)
# ...                                                             ...
# off-target_GGGAACAGGGGCGGTCCGTA    1510: SEQUENCE-driven (GTA) (13)
# off-target_GTAAATTCTCGCGTAACGTT                   1499: neither (5)
# off-target_GTCCATAGGGTCTAGCGCCG    1953: SEQUENCE-driven (ACCG) (4)
# off-target_GTGGATTATCTGACGCGAAT                  3255: neither (13)
# off-target_GTTGATCGACCGATTGCGAT                   2232: neither (2)
#
# [10912 rows x 25 columns]

# %%
if FILTER_TF:
    adata = adata[adata.obs["active"] == True]

# %%
adata.obs["target_gene"].value_counts()
# Out:
# target_gene
# CCN3       6
# DLX3       6
# HNRNPAB    6
# HELZ2      6
# FOXF2      6
#           ..
# ZNF587     2
# ZNF655     2
# ZNF664     2
# ZNF777     2
# ZNF813     2
# Name: count, Length: 223, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
adata.var
# Out:
#                   feature_types  genome      mean  in_matrix       std  \
# gene_name
# DPM1            Gene Expression  GRCh38  0.497299       True  0.738486
# CFH             Gene Expression  GRCh38  0.278384       True  0.554464
# FUCA2           Gene Expression  GRCh38  0.905370       True  1.024018
# NIPAL3          Gene Expression  GRCh38  0.327920       True  0.624273
# LAS1L           Gene Expression  GRCh38  0.263869       True  0.530470
# ...                         ...     ...       ...        ...       ...
# AC010642.2      Gene Expression  GRCh38  0.609991       True  0.836759
# SCO2            Gene Expression  GRCh38  0.259892       True  0.526850
# POLR2J3         Gene Expression  GRCh38  0.579630       True  0.874262
# BX890604.2      Gene Expression  GRCh38  0.288508       True  0.568470
# AUXG01000058.1  Gene Expression  GRCh38  0.207367       True  0.577206
#
#                       cv      fano  pairwise_p_cost  \
# gene_name
# DPM1            1.484995  1.096648              NaN
# CFH             1.991723  1.104338              NaN
# FUCA2           1.131049  1.158215        -2.451047
# NIPAL3          1.903735  1.188450              NaN
# LAS1L           2.010355  1.066434              NaN
# ...                  ...       ...              ...
# AC010642.2      1.371755  1.147828        -2.582480
# SCO2            2.027185  1.068022              NaN
# POLR2J3         1.508309  1.318657        -2.655410
# BX890604.2      1.970376  1.120100              NaN
# AUXG01000058.1  2.783493  1.606649              NaN
#
#                 mean_adjusted_pairwise_p_cost  excess_cv pairwise_chosen  \
# gene_name
# DPM1                                      NaN   0.977718           False
# CFH                                       NaN   1.006758           False
# FUCA2                                0.066219   0.958416           False
# NIPAL3                                    NaN   1.046037           False
# LAS1L                                     NaN   0.996978           False
# ...                                       ...        ...             ...
# AC010642.2                           0.019873   0.981516           False
# SCO2                                      NaN   0.988185           False
# POLR2J3                             -0.042057   1.058342           False
# BX890604.2                                NaN   1.023031           False
# AUXG01000058.1                            NaN   1.222856           False
#
#                         gene_id
# gene_name
# DPM1            ENSG00000000419
# CFH             ENSG00000000971
# FUCA2           ENSG00000001036
# NIPAL3          ENSG00000001461
# LAS1L           ENSG00000001497
# ...                         ...
# AC010642.2      ENSG00000283103
# SCO2            ENSG00000284194
# POLR2J3         ENSG00000285437
# BX890604.2      ENSG00000285756
# AUXG01000058.1  ENSG00000286214
#
# [5424 rows x 12 columns]

# %% [markdown]
# ## Create dictionary of gene -> sequences

# %%
gff = pd.read_csv(
	"GRCh38_latest_genomic.gff",
	sep="\t",
	comment="#",
	header=None,
	names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"]
)

# Filter to only genes
genes = gff[gff["type"] == "gene"]
print(genes.shape)
print(genes.head())
# Out:
# (48106, 9)
#            seqid      source  type  start    end score strand phase  \
# 19  NC_000001.11  BestRefSeq  gene  17369  17436     .      -     .
# 28  NC_000001.11      Gnomon  gene  29774  35418     .      +     .
# 33  NC_000001.11  BestRefSeq  gene  30366  30503     .      +     .
# 38  NC_000001.11  BestRefSeq  gene  34611  36081     .      -     .
# 45  NC_000001.11  BestRefSeq  gene  65419  71585     .      +     .
#
#                                            attributes
# 19  ID=gene-MIR6859-1;Dbxref=GeneID:102466751,HGNC...
# 28  ID=gene-MIR1302-2HG;Dbxref=GeneID:107985730,HG...
# 33  ID=gene-MIR1302-2;Dbxref=GeneID:100302278,HGNC...
# 38  ID=gene-FAM138A;Dbxref=GeneID:645520,HGNC:HGNC...
# 45  ID=gene-OR4F5;Dbxref=GeneID:79501,HGNC:HGNC:14...

# %% [markdown]
# ## Read full genome

# %%
from pyfaidx import Fasta
from Bio.Seq import Seq

genome = Fasta("GRCh38_latest_genomic.fna")

# %%
gene_names = list(adata.var_names)

# %%
len(gene_names)
# Out:
# 5424

# %%
assert len(gene_names) == len(set(gene_names)), "Gene names are not unique!"

# %%
def get_target_gene_sequence(gff_row):
	seqid = gff_row["seqid"]
	start = gff_row["start"]
	strand = gff_row["strand"]
	
	# Get upstream and downstream positions
	upstream_start = max(0, start - BP_considered - 1) # subtracting 1 for 0-based indexing (GFF is 1-based)
	downstream_end = start + BP_considered - 1
	
	# Extract sequence
	sequence = str(genome[seqid][upstream_start:downstream_end])
	
	# If on the negative strand, take the reverse complement
	if strand == "-":
		sequence = str(Seq(sequence).reverse_complement())
	
	return sequence

# %%
gene_sequences = {}
not_found_count = 0
for gene in tqdm(gene_names):
	gene_rows = genes[genes["attributes"].str.contains(f'ID=gene-{gene};')]
	if len(gene_rows) == 0:
		# print(f"No entry found for gene {gene}")
		not_found_count += 1
		continue
	elif len(gene_rows) > 1:
		print(f"Multiple entries found for gene {gene}, taking the first one.")
	gene_row = gene_rows.iloc[0]
	gene_sequence = get_target_gene_sequence(gene_row)
	gene_sequences[gene] = gene_sequence
print(f"Total genes not found: {not_found_count}")
# Out:
# 100%|██████████| 5424/5424 [02:08<00:00, 42.14it/s]
# Total genes not found: 117

# %% [markdown]
# ### save dict to pkl

# %%
import pickle

# %%
with open(f"gene_sequences_{BP_considered*2}bp.pkl", "wb") as f:
    pickle.dump(gene_sequences, f)

# %%
gff = None; genes = None; genome = None
gene_sequences = None

# %% [markdown]
# ## Process the tf's now

# %%
tf_names = list(adata.obs["target_gene"].unique())

# %%
len(tf_names)
# Out:
# 223

# %% [markdown]
# ## Read the rna seq file

# %%
from Bio import SeqIO

# %%
all_records = list(SeqIO.parse("GRCh38_latest_rna.gbff", "gb"))
tf_seqs = {}
for tf_name in tqdm(tf_names):
    for record in all_records:
        for feature in record.features:
            if feature.type == "gene":
                if ("gene" in feature.qualifiers and tf_name in feature.qualifiers["gene"]) or (
                    "gene_synonym" in feature.qualifiers and tf_name in feature.qualifiers["gene_synonym"]
                ):
                    start = feature.location.start
                    end = feature.location.end
                    new_seq_str = str(record.seq[start:end])  # ensure plain Python string
                    if tf_name not in tf_seqs:
                        tf_seqs[tf_name] = new_seq_str
                    else:
                        # take longer sequence if multiple found
                        if (end - start) > len(tf_seqs[tf_name]):
                            tf_seqs[tf_name] = new_seq_str
# Out:
# 100%|██████████| 223/223 [01:27<00:00,  2.55it/s]

# %%
len(tf_names) - len(tf_seqs)
# Out:
# 0

# %%
with open("tf_sequences.pkl", "wb") as f:
    pickle.dump(tf_seqs, f)

# %%
all_records = None
tf_seqs = None

# %% [markdown]
# ## Create a dataframe, with each row having: tf_name, gene_name, gene_expression_change

# %%
df_records = []
for tf_name in tqdm(tf_names):
    tf_data = adata[adata.obs["target_gene"] == tf_name]
    expressions = tf_data.X.mean(axis=0)  # Convert to 1D array
    for gene_idx, gene_name in enumerate(gene_names):
        expression_value = expressions[gene_idx]
        df_records.append([tf_name, gene_name, expression_value])
# Out:
# 100%|██████████| 223/223 [00:01<00:00, 117.33it/s]

# %%
df = pd.DataFrame(df_records, columns=["tf_name", "gene_name", "expression"])

# %%
df.shape
# Out:
# (1209552, 3)

# %%
len(tf_names) * len(gene_names)
# Out:
# 1209552

# %%
df.head(3)
# Out:
#   tf_name gene_name  expression
# 0    AATF      DPM1   -0.124948
# 1    AATF       CFH    0.016431
# 2    AATF     FUCA2   -0.104911

# %%
df.to_parquet("tf_gene_expression.parquet", index=False, engine='pyarrow')
